# %% [markdown]
# # Lecture 15: Chance and Sampling
# v.ekc
#
# Simulation *estimates* probabilities; today we also learn to *calculate* them exactly, then meet random sampling, where probability and data science officially merge.
#
# **Today's sections:**
# 1. Chance, the three rules
# 2. Random sampling
# 3. Distributions: probability vs. empirical
# 4. Large random samples

# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ---
# ## 1. Chance: 3 probabilty rules 🎲
#
# A box holds cards R, B, G; we draw two **without replacement**. For each question we'll simulate first, then calculate, they should agree!
#
# ### 📋 Reference Table
#
# | Rule | Formula | Use when |
# |---|---|---|
# | Multiplication | P(A **and** then B) = P(A) · P(B given A) | both events happen |
# | Addition | P(one of several ways) = sum of the ways | ways don't overlap |
# | Complement | P(at least one) = 1 − P(none) | "at least one" questions |

# %% [markdown]
# Box contains cards labeled R, B, and G. I **draw two cards at random without replacement**.

# %% [markdown]
# ### Chance of two events both occurring
# What is the chance that I get G followed by B?
#
# (both "get G first" and "get B second")

# %%
cards = make_array('R','B','G')

# %%
np.random.choice(cards, 2,replace=False)
# Out:
# array(['R', 'B'],
#       dtype='<U1')

# %% [markdown]
# Wrap the event in a function that returns True/False, then simulate it thousands of times:

# %%
def green_then_blue():
    picks = np.random.choice(cards, 2,replace=False)
    return picks.item(0) =='G' and picks.item(1) =='B'

# %%
outcomes = make_array()

for i in np.arange(10000):
    outcomes = np.append(outcomes,green_then_blue())
    
outcomes
# Out:
# array([ 0.,  1.,  0., ...,  0.,  0.,  0.])

# %% [markdown]
# The fraction of `True`s estimates the probability, compare with the exact multiplication-rule answer:

# %%
sum(outcomes)/10000
# Out:
# 0.1618

# %%
np.average(outcomes)
# Out:
# 0.1618

# %%
1/3*1/2
# Out:
# 0.16666666666666666

# %% [markdown]
# > **Multiplication rule in action:** P(G first) = 1/3, then P(B second given G gone) = 1/2 → 1/3 · 1/2 = 1/6 ≈ what we simulated!

# %% [markdown]
# ### Chance of an event that can happen in multiple ways
# What is the chance that one of the ticket is G and the other is B?

# %%
def green_and_blue():
    picks = np.random.choice(cards, 2,replace=False)
    return (picks.item(0) =='G' and picks.item(1) =='B') or (picks.item(0) =='B' and picks.item(1) =='G')

# %%
outcomes = make_array()

for i in np.arange(10000):
    outcomes = np.append(outcomes,green_and_blue())
    
outcomes
# Out:
# array([ 0.,  0.,  1., ...,  1.,  1.,  1.])

# %% [markdown]
# Average of bools = fraction `True`, compare with the addition-rule answer:

# %%
np.average(outcomes)
# Out:
# 0.33339999999999997

# %%
1/3*1/2 + 1/3*1/2
# Out:
# 0.3333333333333333

# %% [markdown]
# > **Addition rule:** "G then B" and "B then G" are two non-overlapping ways to get {G, B}, so add them: 1/6 + 1/6 = 1/3.

# %% [markdown]
# ### Chance of At Least One Success in Independently Repeated Success/Failure Trials

# %%
# Chance of no sixes in 4 rolls of a die

prob_no_sixes_in_four_rolls = (5/6)**4
prob_no_sixes_in_four_rolls

# %%
# Chance of at least one six in 4 rolls of a die
1-prob_no_sixes_in_four_rolls

# %% [markdown]
# Now scale it up: at least one six in *n* rolls, for n up to 50:

# %%
# Chance of at least one six in n rolls of a die

rolls = np.arange(1, 51, 1)
results = Table().with_columns(
    'Rolls', rolls,
    'Chance of at least one 6', 1 - (5/6)**rolls
)
results

# %%
results.scatter('Rolls')

# %% [markdown]
# > **The complement trick:** "at least one six" is hard to count directly (one six? two? three?), but "no sixes at all" is easy: (5/6)⁴. Subtract from 1 and done. Watch the scatter: with 50 rolls, at least one six is nearly certain.

# %% [markdown]
# ### Try It 1: Ten rolls
#
# 1. Calculate the exact chance of **at least one six in 10 rolls**.
#
# 2. Confirm your answer against the `results` table above.

# %%
# 1. exact chance, 10 rolls

# %%
# 2. check the table

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *Complement first, subtract second.*
#
# ```python
# # 1.
# 1 - (5/6) ** 10
#
# # 2.
# results.where('Rolls', 10)
# ```
#
# </details>

# %% [markdown]
# ---
# ## 2. Random Sampling
#
# From probability to data: a **sample** is a subset of a population. How you choose it is everything.
#
# First, ~13,800 United flights, and some *deterministic* samples (no chance involved):

# %% [markdown]
# We load in a dataset of all United national flights from 6/1/15 to 8/9/15, their destination and how long they were delayed, in minutes.

# %%
united = Table.read_table('united.csv')

#little fancy thing...let's number the rows
united = united.with_column('Row', np.arange(united.num_rows)).move_to_start('Row')
united
# Out:
# Row  | Date   | Flight Number | Destination | Delay
# 0    | 6/1/15 | 73            | HNL         | 257
# 1    | 6/1/15 | 217           | EWR         | 28
# 2    | 6/1/15 | 237           | STL         | -3
# 3    | 6/1/15 | 250           | SAN         | 0
# 4    | 6/1/15 | 267           | PHL         | 64
# 5    | 6/1/15 | 273           | SEA         | -6
# 6    | 6/1/15 | 278           | SEA         | -8
# 7    | 6/1/15 | 292           | EWR         | 12
# 8    | 6/1/15 | 300           | HNL         | 20
# 9    | 6/1/15 | 317           | IND         | -10
# ... (13815 rows omitted)

# %% [markdown]
# Some deterministic samples:

# %%
united.where('Destination', 'HNL')
# Out:
# Row  | Date   | Flight Number | Destination | Delay
# 0    | 6/1/15 | 73            | HNL         | 257
# 8    | 6/1/15 | 300           | HNL         | 20
# 35   | 6/1/15 | 663           | HNL         | 4
# 127  | 6/1/15 | 1670          | HNL         | 3
# 151  | 6/2/15 | 73            | HNL         | 0
# 158  | 6/2/15 | 300           | HNL         | 7
# 232  | 6/2/15 | 1175          | HNL         | 25
# 275  | 6/2/15 | 1670          | HNL         | 186
# 297  | 6/3/15 | 73            | HNL         | 354
# 304  | 6/3/15 | 300           | HNL         | 2
# ... (455 rows omitted)

# %%
united.take(np.arange(0, united.num_rows, 1000))
# Out:
# Row  | Date    | Flight Number | Destination | Delay
# 0    | 6/1/15  | 73            | HNL         | 257
# 1000 | 6/7/15  | 1692          | EWR         | 7
# 2000 | 6/14/15 | 824           | JFK         | -1
# 3000 | 6/21/15 | 217           | EWR         | 5
# 4000 | 6/27/15 | 1401          | SAN         | -4
# 5000 | 7/4/15  | 1614          | LAS         | -2
# 6000 | 7/11/15 | 401           | CLE         | 4
# 7000 | 7/17/15 | 1645          | IAD         | 0
# 8000 | 7/24/15 | 624           | ORD         | 61
# 9000 | 7/30/15 | 1728          | ORD         | 209
# ... (4 rows omitted)

# %%
united.take(make_array(34, 6321, 10040))
# Out:
# Row   | Date    | Flight Number | Destination | Delay
# 34    | 6/1/15  | 650           | AUS         | 44
# 6321  | 7/13/15 | 1124          | SEA         | -7
# 10040 | 8/6/15  | 1216          | LAS         | 2

# %% [markdown]
# A random sample:

# %%
# start at a random flight and then take every 1000 rows

start = np.random.choice(np.arange(1000))
systematic_sample = united.take(np.arange(start, united.num_rows, 1000))
systematic_sample.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Row</th> <th>Date</th> <th>Flight Number</th> <th>Destination</th> <th>Delay</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>262  </td> <td>6/2/15 </td> <td>1581         </td> <td>OGG        </td> <td>0    </td>
#         </tr>
#         <tr>
#             <td>1262 </td> <td>6/9/15 </td> <td>1121         </td> <td>DEN        </td> <td>1    </td>
#         </tr>
#         <tr>
#             <td>2262 </td> <td>6/16/15</td> <td>349          </td> <td>EWR        </td> <td>96   </td>
#         </tr>
#         <tr>
#             <td>3262 </td> <td>6/22/15</td> <td>1673         </td> <td>IAD        </td> <td>-5   </td>
#         </tr>
#         <tr>
#             <td>4262 </td> <td>6/29/15</td> <td>864          </td> <td>BOS        </td> <td>34   </td>
#         </tr>
#         <tr>
#             <td>5262 </td> <td>7/6/15 </td> <td>1415         </td> <td>PDX        </td> <td>89   </td>
#         </tr>
#         <tr>
#             <td>6262 </td> <td>7/13/15</td> <td>322          </td> <td>IAH        </td> <td>6    </td>
#         </tr>
#         <tr>
#             <td>7262 </td> <td>7/19/15</td> <td>1438         </td> <td>EWR        </td> <td>-4   </td>
#         </tr>
#         <tr>
#             <td>8262 </td> <td>7/26/15</td> <td>294          </td> <td>DFW        </td> <td>7    </td>
#         </tr>
#         <tr>
#             <td>9262 </td> <td>8/1/15 </td> <td>1227         </td> <td>EWR        </td> <td>-5   </td>
#         </tr>
#         <tr>
#             <td>10262</td> <td>8/7/15 </td> <td>1751         </td> <td>LAS        </td> <td>-2   </td>
#         </tr>
#         <tr>
#             <td>11262</td> <td>8/14/15</td> <td>650          </td> <td>AUS        </td> <td>-1   </td>
#         </tr>
#         <tr>
#             <td>12262</td> <td>8/20/15</td> <td>1994         </td> <td>ORD        </td> <td>9    </td>
#         </tr>
#         <tr>
#             <td>13262</td> <td>8/27/15</td> <td>1960         </td> <td>LAX        </td> <td>1    </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# Or we can use `table.sample(n, with_replacement=True)`

# %%
# the table method table.sample(sample_size, with_replacement=True)
united.sample(5, with_replacement=False).sort('Row')
# Out:
# Row   | Date    | Flight Number | Destination | Delay
# 1480  | 6/10/15 | 1753          | MCO         | 34
# 2747  | 6/19/15 | 502           | JFK         | 0
# 8855  | 7/29/15 | 1930          | IAD         | 3
# 11533 | 8/16/15 | 395           | LAS         | -6
# 12546 | 8/23/15 | 392           | LAS         | -4

# %% [markdown]
# OrRrR we can use `np.random.choice(arr, n, replace=True)`

# %%
# random index of rows
#    np.random.choice(array_to_sample, sample_size, replace=True) < default

united.take(np.random.choice(np.arange(united.num_rows), 5, replace=False)).sort('Row')
# Out:
# Row  | Date    | Flight Number | Destination | Delay
# 2621 | 6/18/15 | 1073          | BOS         | 79
# 2776 | 6/19/15 | 1062          | MSP         | 30
# 3367 | 6/23/15 | 1074          | ORD         | 10
# 5392 | 7/7/15  | 788           | BOS         | 19
# 8262 | 7/26/15 | 294           | DFW         | 7

# %% [markdown]
# > **Deterministic vs. random:** `where` and `take` with fixed positions give the same rows every time. The systematic sample above *is* random, the random start decides everything that follows.

# %% [markdown]
# ### Try It 2: Every 500th flight
#
# 1. Build a systematic **random** sample: every 500th row, starting from a random position among the first 500.
#
# 2. Is the JFK table above a random sample? Why or why not?

# %%
# 1. every 500th from a random start

# %% [markdown]
# *2. Your interpretation: (double-click to edit)*

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *The random start is the only randomness, and it's enough.*
#
# ```python
# # 1.
# start = np.random.choice(np.arange(500))
# united.take(np.arange(start, united.num_rows, 500))
# ```
#
# *2. No, `where('Destination', 'JFK')` returns the same rows every single time; no chance is involved.*
#
# </details>

# %% [markdown]
# ---
# ## 3. Distributions: Probability vs. Empirical
#
# A die has a **probability distribution**: exactly 1/6 per face, forever. A *sample* of rolls has an **empirical distribution**: whatever actually happened. Watch them differ, then converge.

# %%
die = Table().with_column('Face', np.arange(1, 7))
die
# Out:
# Face
# 1
# 2
# 3
# 4
# 5
# 6

# %%
die.sample(10)
# Out:
# Face
# 2
# 3
# 2
# 2
# 1
# 5
# 3
# 1
# 4
# 4

# %% [markdown]
# Histograms, first the exact probability distribution:

# %%
# die.hist()

roll_bins = np.arange(0.5, 6.6, 1)
die.hist(bins=roll_bins)

# %% [markdown]
# Now roll only 10 times and compare:

# %%
die.sample(10).hist(bins=roll_bins)

# %% [markdown]
# ### Try It 3: More rolls...
#
# 1. Simulate 1000 rolls of a die and plot the empirical distribution. What do you notice compared to 10 rolls?
#
# 2. Now 10,000 rolls. What do you notice?

# %%
# Fill in: replace the ... 
...

# %%
# Fill in: replace the ... 
...

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *`die.sample(n)` rolls n times; more rolls → flatter, closer to the true 1/6-per-face distribution.*
#
# ```python
# # 1.
# die.sample(1000).hist(bins=roll_bins)
#
# # 2.
# die.sample(10000).hist(bins=roll_bins)
# ```
#
# </details>
#
# > **The Law of Averages**: as the number of draws grows, the empirical distribution settles toward the probability distribution. This is *why* simulation works.

# %% [markdown]
# ---
# ## 4. Large Random Samples
#
# The same idea for real data: the flight delays have a fixed (population) distribution, and a large enough random sample looks just like it.

# %%
united
# Out:
# Row  | Date   | Flight Number | Destination | Delay
# 0    | 6/1/15 | 73            | HNL         | 257
# 1    | 6/1/15 | 217           | EWR         | 28
# 2    | 6/1/15 | 237           | STL         | -3
# 3    | 6/1/15 | 250           | SAN         | 0
# 4    | 6/1/15 | 267           | PHL         | 64
# 5    | 6/1/15 | 273           | SEA         | -6
# 6    | 6/1/15 | 278           | SEA         | -8
# 7    | 6/1/15 | 292           | EWR         | 12
# 8    | 6/1/15 | 300           | HNL         | 20
# 9    | 6/1/15 | 317           | IND         | -10
# ... (13815 rows omitted)

# %%
united_bins = np.arange(-20, 201, 5)
united.hist('Delay', bins = united_bins)

# %% [markdown]
# The population's own numbers (min, max, mean delay):

# %%
min(united.column('Delay'))

# %%
max(united.column('Delay'))

# %%
np.average(united.column('Delay'))

# %% [markdown]
# ### Try It 4: Sample the flights ✈️
#
# 1. Draw a sample of 10 flights and plot the distribution of delays. What do you observe?
#
# 2. Now a sample of 1000. What changed?

# %%
# Fill in: replace the ... 
...

# %%
# Fill in: replace the ... 
...

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *Small samples are noisy and can look nothing like the population; big ones are near-copies.*
#
# ```python
# # 1.
# united.sample(10).hist('Delay', bins=united_bins)
#
# # 2.
# united.sample(1000).hist('Delay', bins=united_bins)
# ```
#
# </details>
#
# ---
# > **Today's takeaway:** three rules calculate chances, simulation checks them, and the Law of Averages guarantees that large random samples mirror their population. That guarantee is the foundation of inference, starting next lecture.
#
# ## Appendix — Quick Reference
#
# Full `datascience` docs: [data8.org/datascience](https://data8.org/datascience/)
#
# ### Minimal template — sample and compare
# ```python
# t.sample(n)                      # n random rows (with replacement)
# t.sample(n).hist('col', bins=b)  # empirical distribution
# ```
