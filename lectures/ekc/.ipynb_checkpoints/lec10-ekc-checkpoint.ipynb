# %% [markdown]
# # Lecture 10: Prediction and Groups
# v.ekc
#
# Two things today: making **predictions** from data (using functions + `apply` from last time), and **grouping**, the fastest way to summarize a table.
#
# **Today's sections:**
# 1. Prediction — child heights
# 2. Prediction accuracy
# 3. Grouping by one column
# 4. Grouping by two columns

# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---
# ## 1. Prediction: Child Heights 👨‍👩‍👧
#
# This is Francis Galton's famous 1880s dataset of parents' and children's heights, the data that launched regression. Strategy: to predict a child's height, look at children whose parents were about the same height, and average them.

# %%
families = Table.read_table('family_heights.csv')
families
# Out:
# family | father | mother | child | children | order | sex
# 1      | 78.5   | 67     | 73.2  | 4        | 1     | male
# 1      | 78.5   | 67     | 69.2  | 4        | 2     | female
# 1      | 78.5   | 67     | 69    | 4        | 3     | female
# 1      | 78.5   | 67     | 69    | 4        | 4     | female
# 2      | 75.5   | 66.5   | 73.5  | 4        | 1     | male
# 2      | 75.5   | 66.5   | 72.5  | 4        | 2     | male
# 2      | 75.5   | 66.5   | 65.5  | 4        | 3     | female
# 2      | 75.5   | 66.5   | 65.5  | 4        | 4     | female
# 3      | 75     | 64     | 71    | 2        | 1     | male
# 3      | 75     | 64     | 68    | 2        | 2     | female
# ... (924 rows omitted)

# %% [markdown]
# Mother's and father's heights → one "parent average" per family:

# %%
parent_avgs = (families.column('father') + families.column('mother'))/2
parent_avgs
# Out:
# array([ 72.75,  72.75,  72.75,  72.75,  71.  ,  71.  ,  71.  ,  71.  ,
#         69.5 ,  69.5 ,  69.5 ,  69.5 ,  69.5 ,  69.5 ,  69.5 ,  66.75,
#         66.75,  66.75,  66.75,  66.75,  66.75,  71.  ,  71.  ,  71.  ,
#         71.  ,  71.  ,  71.  ,  71.  ,  70.25,  70.25,  70.25,  70.25,
#         69.75,  68.  ,  68.  ,  68.  ,  68.  ,  68.  ,  68.  ,  68.  ,
#         68.  ,  67.5 ,  70.  ,  70.  ,  70.  ,  70.  ,  69.75,  69.75,
#         69.75,  69.  ,  69.  ,  69.  ,  69.  ,  69.  ,  69.  ,  69.  ,
#         69.  ,  69.  ,  68.75,  68.75,  68.75,  68.75,  68.75,  68.75,
#         68.5 ,  68.5 ,  68.5 ,  68.1 ,  70.85,  70.85,  70.85,  70.85,
#         70.85,  70.85,  70.85,  70.85,  70.  ,  70.  ,  70.  ,  69.5 ,
#         69.5 ,  69.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,
#         68.5 ,  68.75,  68.  ,  68.  ,  67.5 ,  67.5 ,  67.5 ,  67.5 ,
#         67.5 ,  67.5 ,  67.5 ,  67.5 ,  67.5 ,  67.5 ,  67.5 ,  67.5 ,
#         67.5 ,  67.5 ,  68.  ,  68.  ,  68.  ,  67.  ,  67.25,  67.25,
#         67.25,  67.25,  67.25,  67.25,  67.  ,  67.  ,  67.  ,  67.  ,
#         67.  ,  67.  ,  67.  ,  67.  ,  67.  ,  67.  ,  66.5 ,  70.  ,
#         70.  ,  70.  ,  70.  ,  70.  ,  69.  ,  69.  ,  69.  ,  69.  ,
#         68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,
#         68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,  68.5 ,
#         68.5 ,  68.6 ,  68.25,  68.25,  68.25,  68.25,  68.25,  68.25,
#         68.5 ,  68.5 ,  68.25,  68.25,  68.  ,  68.  ,  68.  ,  67.5 ,
#         67.5 ,  67.5 ,  67.5 ,  67.5 ,  67.5 ,  67.5 ,  67.5 ,
.5 ,  65.5 ,  65.5 ,  65.5 ,  65.5 ,  65.5 ,  65.5 ,  65.5 ,
#         65.5 ,  65.  ,  65.  ,  65.  ,  65.  ,  65.  ,  65.  ,  65.  ,
#         65.  ,  65.  ,  65.25,  65.25,  65.  ,  65.  ,  65.  ,  65.  ,
#         65.  ,  65.  ,  64.5 ,  64.5 ,  64.5 ,  64.5 ,  64.5 ,  64.5 ,
#         64.  ,  64.  ,  64.  ,  64.  ,  64.  ,  64.25,  64.25,  64.25,
#         64.25,  62.75,  62.75,  62.75,  62.75,  62.75,  64.  ,  64.  ,
#         64.  ,  64.  ,  64.  ,  64.  ,  64.  ,  64.  ,  64.  ,  64.  ,
#         64.  ,  64.  ,  64.  ,  64.  ,  63.5 ,  62.  ,  62.  ,  63.25,
#         63.25,  64.  ,  64.  ,  64.  ,  62.75,  62.75])

# %%
heights = Table().with_columns(
    'Parent Average', parent_avgs,
    'Child', families.column('child'),
    'Sex', families.column('sex')
)
heights
# Out:
# Parent Average | Child | Sex
# 72.75          | 73.2  | male
# 72.75          | 69.2  | female
# 72.75          | 69    | female
# 72.75          | 69    | female
# 71             | 73.5  | male
# 71             | 72.5  | male
# 71             | 65.5  | female
# 71             | 65.5  | female
# 69.5           | 71    | male
# 69.5           | 68    | female
# ... (924 rows omitted)

# %%
heights.scatter('Parent Average', 'Child')

# %% [markdown]
# 900+ families as dots, then zoom into one strip of similar parents:

# %%
heights.scatter('Parent Average', 'Child')
plots.plot([67.5, 67.5], [50, 85], color='red', lw=2)
plots.plot([68.5, 68.5], [50, 85], color='red', lw=2);

# %% [markdown]
# Average the children in that strip: that's our prediction for 68-inch parents:

# %%
nearby = heights.where('Parent Average', are.between(67.5, 68.5))
nearby_mean = np.average(nearby.column('Child'))
nearby_mean
# Out:
# 67.620000000000005

# %%
heights.scatter('Parent Average', 'Child')
plots.plot([67.5, 67.5], [50, 85], color='red', lw=2)
plots.plot([68.5, 68.5], [50, 85], color='red', lw=2)
plots.scatter(68, nearby_mean, color='red', s=50);

# %% [markdown]
# ### Try It 1: A prediction function 😊
#
# 1. What if you wanted to predict the child's height for parents with average height 66 (I'm 62 inches and my husband is 70 inches), 70, and 73? Define a function `predict(h)` that averages the children of parents within ±0.5 inches of `h`.

# %%
def predict(h):
    ...
    return ...

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *Filter to the nearby parents, then average their children, exactly what we did by hand for 68.*
#
# ```python
# def predict(h):
#     nearby = heights.where('Parent Average', are.between(h - 0.5, h + 0.5))
#     return np.average(nearby.column('Child'))
# ```
#
# </details>
#
# Run the next cell so the rest of the lecture works:

# %%
# run me: needed below
def predict(h):
    nearby = heights.where('Parent Average', are.between(h - 0.5, h + 0.5))   # filter table to only include children whos parents are 
                                                                              #    within the zone of interest
    return np.average(nearby.column('Child'))                                 # average those children's heights!

# %%
predict(66)
# Out:
# 66.086407766990291

# %%
predict(70)
# Out:
# 68.561904761904756

# %%
predict(73)
# Out:
# 70.099999999999994

# %% [markdown]
# ### Try It 2: Predict every row 😊
#
# 1. How would you make a prediction for **each row** of parents in the `heights` table? (Hint: yesterday's newest method!)

# %%
# 1. one prediction per row
# Out:
# array([ 70.1       ,  70.1       ,  70.1       ,  70.1       ,
#         70.41578947,  70.41578947,  70.41578947,  70.41578947,
#         68.5025    ,  68.5025    ,  68.5025    ,  68.5025    ,
#         68.5025    ,  68.5025    ,  68.5025    ,  66.48230453,
#         66.48230453,  66.48230453,  66.48230453,  66.48230453,
#         66.48230453,
#         65.83829787,  65.83829787,  66.15932203,  66.15932203,
#         65.83829787,  65.83829787,  65.83829787,  65.83829787,
#         65.83829787,  65.83829787,  65.31573034,  65.31573034,
#         65.31573034,  65.31573034,  65.31573034,  65.31573034,
#         64.915     ,  64.915     ,  64.915     ,  64.915     ,
#         64.915     ,  65.20649351,  65.20649351,  65.20649351,
#         65.20649351,  64.22962963,  64.22962963,  64.22962963,
#         64.22962963,  64.22962963,  64.915     ,  64.915     ,
#         64.915     ,  64.915     ,  64.915     ,  64.915     ,
#         64.915     ,  64.915     ,  64.915     ,  64.915     ,
#         64.915     ,  64.915     ,  64.915     ,  64.915     ,
#         65.11      ,  63.        ,  63.        ,  64.748     ,
#         64.748     ,  64.915     ,  64.915     ,  64.915     ,
#         64.22962963,  64.22962963])

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *`apply` runs `predict` on every Parent Average: 900+ predictions in one line.*
#
# ```python
# predicted_heights = heights.apply(predict, 'Parent Average')
# ```
#
# </details>
#
# Run the next cell to continue:

# %%
# run me: needed below
predicted_heights = heights.apply(predict, 'Parent Average')

# %%
heights = heights.with_column('Prediction', predicted_heights)
heights
# Out:
# Parent Average | Child | Sex    | Smarter Prediction | Smarter Errors | Prediction
# 72.75          | 73.2  | male   | 73.2               | 0              | 70.1
# 72.75          | 69.2  | female | 69.0667            | 0.133333       | 70.1
# 72.75          | 69    | female | 69.0667            | -0.0666667     | 70.1
# 72.75          | 69    | female | 69.0667            | -0.0666667     | 70.1
# 71             | 73.5  | male   | 73.4889            | 0.0111111      | 70.4158
# 71             | 72.5  | male   | 73.4889            | -0.988889      | 70.4158
# 71             | 65.5  | female | 67.65              | -2.15          | 70.4158
# 71             | 65.5  | female | 67.65              | -2.15          | 70.4158
# 69.5           | 71    | male   | 70.7955            | 0.204545       | 68.5025
# 69.5           | 68    | female | 65.7               | 2.3            | 68.5025
# ... (924 rows omitted)

# %%
# plot 'Parent Average' overlaid with both 'Child' and 'Prediction'

heights.select('Parent Average', 'Child', 'Prediction').scatter('Parent Average')

# %% [markdown]
# ---
# ## 2. Prediction Accuracy
#
# Good predictions have small errors. Let's *measure* ours, with a function, of course!

# %%
def difference(predicted, actual):
    return predicted - actual

# %%
pred_errs = heights.apply(difference, 'Prediction', 'Child')
heights = heights.with_column('errors',pred_errs)
heights
# Out:
# Parent Average | Child | Sex    | Smarter Prediction | Smarter Errors | Prediction | errors
# 72.75          | 73.2  | male   | 73.2               | 0              | 70.1       | -3.1
# 72.75          | 69.2  | female | 69.0667            | 0.133333       | 70.1       | 0.9
# 72.75          | 69    | female | 69.0667            | -0.0666667     | 70.1       | 1.1
# 72.75          | 69    | female | 69.0667            | -0.0666667     | 70.1       | 1.1
# 71             | 73.5  | male   | 73.4889            | 0.0111111      | 70.4158    | -3.08421
# 71             | 72.5  | male   | 73.4889            | -0.988889      | 70.4158    | -2.08421
# 71             | 65.5  | female | 67.65              | -2.15          | 70.4158    | 4.91579
# 71             | 65.5  | female | 67.65              | -2.15          | 70.4158    | 4.91579
# 69.5           | 71    | male   | 70.7955            | 0.204545       | 68.5025    | -2.4975
# 69.5           | 68    | female | 65.7               | 2.3            | 68.5025    | 0.5025
# ... (924 rows omitted)

# %% [markdown]
# Errors in hand, look at their distribution, then split it by sex:

# %%
heights.hist('errors')

# %%
heights.hist('errors', group='Sex')

# %% [markdown]
# What are the errors by `male` and `female` telling us about our function `predict`? Is there overestimating or underestimating for a specific group?

# %% [markdown]
# ### Try It 3: Predict smarter 🤓
#
# The error histogram grouped by sex shows we're systematically off. Can we do better?
#
# 1. Write `predict_smarter(h, s)` that only averages nearby children of sex `s`. Does it shrink the errors?

# %%
def predict_smarter(h, s):
    nearby = ...
    nearby_same_sex = ...
    return ...

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *Same as `predict`, plus one more `where` for the sex.*
#
# ```python
# def predict_smarter(h, s):
#     nearby = heights.where('Parent Average', are.between(h - 0.5, h + 0.5))
#     nearby_same_sex = nearby.where('Sex', s)
#     return np.average(nearby_same_sex.column('Child'))
# ```
#
# </details>
#
# Run the next cell to continue:

# %%
# run me: needed below
def predict_smarter(h, s):
    nearby = heights.where('Parent Average', are.between(h - 0.5, h + 0.5))
    nearby_same_sex = nearby.where('Sex', s)
    return np.average(nearby_same_sex.column('Child'))

# %%
predict_smarter(68, 'female')
# Out:
# 64.983516483516482

# %%
predict_smarter(68, 'male')
# Out:
# 70.172340425531914

# %% [markdown]
# Now apply it across every row and measure the new errors:

# %%
# use table.apply(function, arg1, arg2)   <--- use .apply to feed in multiple arguments!

smarter_predicted_heights = heights.apply(predict_smarter, 'Parent Average', 'Sex')

# add the sex-based predictions to the table
heights = heights.with_column('Smarter Prediction', smarter_predicted_heights)

# %%
# grab the errors again

smarter_pred_errs = heights.apply(difference, 'Child', 'Smarter Prediction')
heights = heights.with_column('Smarter Errors', smarter_pred_errs)

# %%
# new errors
heights.hist('Smarter Errors',group='Sex')

# old errors
heights.hist('errors', group='Sex')

# %% [markdown]
# > **Compare the two error histograms:** grouping by sex centered both distributions around 0. Using more relevant data to make better predictions!

# %% [markdown]
# ---
# ## 3. Grouping by One Column
#
# `group` counted categories in Lecture 8. Give it a **second argument**, a function, and it summarizes each group any way you like.
#
# ### 📋 Reference Table
#
# | Code | What it does |
# |---|---|
# | `t.group('col')` | count rows per category |
# | `t.group('col', np.average)` | average of every other column, per category |
# | `t.group('col', np.min)` | min per category |
# | `t.group(['c1', 'c2'])` | count every combination of two columns |
# | `t.apply(f, 'col')` | (from last time) function across a column |

# %%
cones = Table.read_table('cones.csv').drop('Color')
cones
# Out:
# Flavor     | Price
# strawberry | 3.55
# chocolate  | 4.75
# chocolate  | 5.25
# strawberry | 5.25
# chocolate  | 5.25
# bubblegum  | 4.75

# %%
cones.group('Flavor')
# Out:
# Flavor     | count
# bubblegum  | 1
# chocolate  | 3
# strawberry | 2

# %% [markdown]
# A second argument = a summary function (average, min, whatever you need):

# %%
cones.group('Flavor', np.average)
# Out:
# Flavor     | Price average
# bubblegum  | 4.75
# chocolate  | 5.08333
# strawberry | 4.4

# %%
cones.group('Flavor', np.min)
# Out:
# Flavor     | Price min
# bubblegum  | 4.75
# chocolate  | 4.75
# strawberry | 3.55

# %% [markdown]
# Another example

# %%
heights.select('Sex','Child').group('Sex',np.average)
# Out:
# Sex    | Child average
# female | 64.104
# male   | 69.2341

# %% [markdown]
# ### Grouping the Welcome Survey
#
# Back to our class data: grouping answers real questions fast.

# %%
survey = Table.read_table('data111_survey_fa26.csv')
survey.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Timestamp</th> <th>Pets</th> <th>Handedness</th> <th>Extroversion</th> <th>Texts</th> <th>Hours of Sleep</th> <th>Sleep Position</th> <th>Pant Leg</th> <th>Piercings</th> <th>Food Preference</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>8/24/2026 16:41:18</td> <td>Cat                  </td> <td>Right     </td> <td>3           </td> <td>1    </td> <td>8             </td> <td>On my left side          </td> <td>Right leg         </td> <td>2        </td> <td>Sweet          </td>
#         </tr>
#         <tr>
#             <td>8/24/2026 21:40:00</td> <td>Fish                 </td> <td>Left      </td> <td>8           </td> <td>2    </td> <td>4.5           </td> <td>On my left side          </td> <td>Right leg         </td> <td>0        </td> <td>Savory         </td>
#         </tr>
#         <tr>
#             <td>8/25/2026 9:31:37 </td> <td>Dog, Cat, Bird, Other</td> <td>Right     </td> <td>5           </td> <td>3    </td> <td>7.5           </td> <td>On my right side         </td> <td>I don't wear pants</td> <td>0        </td> <td>Sweet          </td>
#         </tr>
#         <tr>
#             <td>8/25/2026 10:29:55</td> <td>Dog, Cat             </td> <td>Left      </td> <td>8           </td> <td>6    </td> <td>7             </td> <td>On my right side         </td> <td>Left leg          </td> <td>0        </td> <td>Sweet          </td>
#         </tr>
#         <tr>
#             <td>8/25/2026 10:38:04</td> <td>Cat                  </td> <td>Right     </td> <td>8           </td> <td>9    </td> <td>7.9           </td> <td>On my back like a vampire</td> <td>Right leg         </td> <td>0        </td> <td>Savory         </td>
#         </tr>
#         <tr>
#             <td>8/25/2026 11:29:41</td> <td>Dog                  </td> <td>Right     </td> <td>7           </td> <td>4    </td> <td>8.5           </td> <td>On my right side         </td> <td>I don't wear pants</td> <td>2        </td> <td>Savory         </td>
#         </tr>
#         <tr>
#             <td>8/25/2026 12:20:05</td> <td>Dog                  </td> <td>Right     </td> <td>7           </td> <td>10   </td> <td>8.5           </td> <td>On my right side         </td> <td>Right leg         </td> <td>0        </td> <td>Savory         </td>
#         </tr>
#         <tr>
#             <td>8/25/2026 14:08:02</td> <td>Cat, Bird, Other     </td> <td>Right     </td> <td>4           </td> <td>5    </td> <td>5             </td> <td>On my stomach            </td> <td>Left leg          </td> <td>18       </td> <td>Sweet          </td>
#         </tr>
#         <tr>
#             <td>8/26/2026 10:02:55</td> <td>Dog, Cat, Bird, Other</td> <td>Right     </td> <td>5           </td> <td>3    </td> <td>7.5           </td> <td>On my right side         </td> <td>I don't wear pants</td> <td>0        </td> <td>Sweet          </td>
#         </tr>
#         <tr>
#             <td>8/26/2026 10:03:08</td> <td>Cat                  </td> <td>Right     </td> <td>4           </td> <td>6    </td> <td>7.5           </td> <td>On my back like a vampire</td> <td>Right leg         </td> <td>9        </td> <td>Sweet          </td>
#         </tr>
#         <tr>
#             <td>8/26/2026 10:03:58</td> <td>Dog                  </td> <td>Right     </td> <td>3           </td> <td>2    </td> <td>6.5           </td> <td>On my left side          </td> <td>Right leg         </td> <td>1        </td> <td>Sweet          </td>
#         </tr>
#         <tr>
#             <td>8/26/2026 10:06:39</td> <td>nan                  </td> <td>Right     </td> <td>7           </td> <td>2    </td> <td>7             </td> <td>On my stomach            </td> <td>Right leg         </td> <td>0        </td> <td>Savory         </td>
#         </tr>
#         <tr>
#             <td>8/28/2026 18:26:03</td> <td>Dog                  </td> <td>Right     </td> <td>2           </td> <td>5    </td> <td>7.5           </td> <td>On my stomach            </td> <td>Right leg         </td> <td>2        </td> <td>Savory         </td>
#         </tr>
#         <tr>
#             <td>8/28/2026 20:05:10</td> <td>nan                  </td> <td>Right     </td> <td>9           </td> <td>4    </td> <td>6             </td> <td>On my stomach            </td> <td>Right leg         </td> <td>0        </td> <td>Sweet          </td>
#         </tr>
#         <tr>
#             <td>8/28/2026 20:06:41</td> <td>nan                  </td> <td>Right     </td> <td>8           </td> <td>4    </td> <td>6             </td> <td>On my stomach            </td> <td>Right leg         </td> <td>0        </td> <td>Sweet          </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# How extroverted is the class? Distribution first, then group-averages:

# %%
survey.hist('Extroversion')

# %%
by_extra = survey.group('Extroversion', np.average)
by_extra

# survey.select('Extroversion', 'Texts').group('Extroversion', np.average)
# Out:
# Extroversion | Timestamp average | Pets average | Handedness average | Texts average | Hours of Sleep average | Sleep Position average | Pant Leg average | Piercings average | Food Preference average
# 2            |                   |              |                    | 5             | 7.5                    |                        |                  | 2                 |
# 3            |                   |              |                    | 1.5           | 7.25                   |                        |                  | 1.5               |
# 4            |                   |              |                    | 5.5           | 6.25                   |                        |                  | 13.5              |
# 5            |                   |              |                    | 3             | 7.5                    |                        |                  | 0                 |
# 7            |                   |              |                    | 5.33333       | 8                      |                        |                  | 0.666667          |
# 8            |                   |              |                    | 5.25          | 6.35                   |                        |                  | 0                 |
# 9            |                   |              |                    | 4             | 6                      |                        |                  | 0                 |

# %% [markdown]
# Does extroversion track texting? Plot the grouped averages:

# %%
by_extra.plot('Extroversion', 'Texts average')

# %% [markdown]
# Same machine on the sleep questions (count, average, chart):

# %%
survey.group("Sleep Position")
# Out:
# Sleep Position            | count
# On my back like a vampire | 2
# On my left side           | 3
# On my right side          | 5
# On my stomach             | 5

# %%
survey.select("Sleep Position", "Hours of Sleep").group('Sleep Position', np.average)
# Out:
# Sleep Position            | Hours of Sleep average
# On my back like a vampire | 7.7
# On my left side           | 6.33333
# On my right side          | 7.8
# On my stomach             | 6.3

# %%
survey.select("Sleep Position", "Hours of Sleep").group('Sleep Position', np.average).barh('Sleep Position')

# %% [markdown]
# ### Try It 4: Group the survey 😊
#
# 1. Which sleep position gets the most sleep on average? Answer with code from the grouped table.
#
# 2. How many **left-handed** students are in the survey?
#
# 3. Your choice: group the survey by any column that interests you and pull out one finding.

# %%
# 1. best-rested sleep position

# %%
# 2. left-handed count

# %%
# 3. your choice

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *Grouped tables are still tables, sort them, filter them, read them.*
#
# ```python
# # 1.
# sp = survey.select('Sleep Position', 'Hours of Sleep').group('Sleep Position', np.average)
# sp.sort('Hours of Sleep average', descending=True).column('Sleep Position').item(0)
#
# # 2.
# survey.group('Handedness')   # read the left-handed row's count
#
# # 3. one of many right answers
# survey.select('Handedness', 'Piercings').group('Handedness', np.average)
# ```
#
# </details>

# %% [markdown]
# ---
# ### A quick detour: Lists
#
# Arrays hold one type; **lists** (square brackets) hold anything, including the two column names we're about to hand to `group`.

# %%
[1, 5, 'hello', 5.0]

# %%
[1, 5, 'hello', 5.0, make_array(1,2,3)]

# %% [markdown]
# ---
# ## 4. Grouping by Two Columns
#
# Pass `group` a *list* of two labels and it counts every combination.

# %% [markdown]
# Do right-handed people tend to sleep on their left side and left-handed people sleep on their right?

# %%
survey.group(['Handedness', 'Sleep Position']).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Handedness</th> <th>Sleep Position</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Left      </td> <td>On my left side          </td> <td>1    </td>
#         </tr>
#         <tr>
#             <td>Left      </td> <td>On my right side         </td> <td>1    </td>
#         </tr>
#         <tr>
#             <td>Right     </td> <td>On my back like a vampire</td> <td>2    </td>
#         </tr>
#         <tr>
#             <td>Right     </td> <td>On my left side          </td> <td>2    </td>
#         </tr>
#         <tr>
#             <td>Right     </td> <td>On my right side         </td> <td>4    </td>
#         </tr>
#         <tr>
#             <td>Right     </td> <td>On my stomach            </td> <td>5    </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Try It 5: Pets, predicted 🐶
#
# Below is a small `pets` table (8 rows).
#
# 1. **Before running anything:** how many rows will `pets.group('Type')` have? What about `pets.group(['Type', 'Color'])`?
# 2. Check your answers with code.

# %%
pets = Table().with_columns('Type',make_array('dog','cat','dog','dog','bird','cat','dog','bird'),
                            'Color',make_array('black','black','multi','black','multi','black','white','multi'),
                           'Num Legs', make_array(4,4,4,3,2,4,4,2),
                           'Length', make_array(20,16,50,34,8,18,44,7),
                           'Cute score',make_array(8,7,9,7,8,10,3,8)
                           )
pets

# %%
# 2. check your prediction

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *One row per distinct value (3 types), one row per distinct **combination** (7 of the 3×3 possible combos actually occur).*
#
# ```python
# # 2.
# pets.group('Type')             # 3 rows
# pets.group(['Type', 'Color'])  # 7 rows
# ```
#
# </details>

# %% [markdown]
# ---
# > **Today's takeaway:** `apply` turns a function into a column; `group` turns categories into summaries. Homework 4 combines both, if the burrito questions feel hard, re-run sections 1 and 3 here first.
#
# ## Appendix — Quick Reference
#
# Full `datascience` docs: [data8.org/datascience](https://data8.org/datascience/)
#
# ### Minimal template — grouped summary
# ```python
# t.select('category', 'value').group('category', np.average).barh('category')
# ```
